# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
with open('../JSON/MVP/final_mvp.json', 'r') as loadFile:
    train_data =  pd.DataFrame(json.load(loadFile))

# %%
train_data.describe()
train_data.set_index('Player')
# Out:
#                       Pos  Age   Tm     G    GS    MP    FG   FGA    FG%   3P  \
# Player
# LeBron James           SF   24  CLE  81.0  81.0  37.7   9.7  19.9  0.489  1.6
# Kevin Durant           SF   20  OKC  74.0  74.0  39.0   8.9  18.8  0.476  1.3
# Chauncey Billups       PG   32  TOT  79.0  79.0  35.3   5.2  12.4  0.418  2.1
# Stephen Curry          PG   27  GSW  79.0  79.0  34.2  10.2  20.2  0.504  5.1
# Giannis Antetokounmpo  PG   21  MIL  80.0  79.0  35.3   6.4  12.7  0.506  0.4
# John Wall              PG   25  WAS  77.0  77.0  36.2   7.4  17.5  0.424  1.5
# Anthony Davis           C   22  NOP  61.0  61.0  35.5   9.2  18.6  0.493  0.6
# Kevin Durant           SF   27  OKC  72.0  72.0  35.8   9.7  19.2  0.505  2.6
# DeMar DeRozan          SG   26  TOR  78.0  78.0  35.9   7.9  17.7  0.446  0.6
# James Harden           PG   27  HOU  81.0  81.0  36.4   8.3  18.9  0.440  3.2
# LeBron James           SF   32  CLE  74.0  74.0  37.8   9.9  18.2  0.548  1.7
# Anthony Davis           C   23  NOP  75.0  75.0  36.1  10.3  20.3  0.505  0.5
# Damian Lillard         PG   26  POR  75.0  75.0  35.9   8.8  19.8  0.444  2.9
# Chris Bosh              C   24  TOR  77.0  77.0  38.0   8.0  16.4  0.487  0.2
# Russell Westbrook      PG   28  OKC  81.0  81.0  34.6  10.2  24.0  0.425  2.5
# Giannis Antetokounmpo  SF   22  MIL  80.0  80.0  35.6   8.2  15.7  0.521  0.6
# Kevin Durant           PF   28  GSW  62.0  62.0  33.4   8.9  16.5  0.537  1.9
# DeMar DeRozan          SG   27  TOR  74.0  74.0  35.4   9.7  20.9  0.467  0.4
# LaMarcus Aldridge      PF   31  SAS  72.0  72.0  32.4   6.9  14.6  0.477  0.3
# Jimmy Butler           SF   27  CHI  76.0  75.0  37.0   7.5  16.5  0.455  1.2
# Stephen Curry          PG   28  GSW  79.0  79.0  33.4   8.5  18.3  0.468  4.1
# Joel Embiid             C   22  PHI  31.0  31.0  25.4   6.5  13.8  0.466  1.2
# Victor Oladipo         SG   24  OKC  67.0  67.0  33.2   6.1  13.9  0.442  1.9
# Giannis Antetokounmpo  PF   23  MIL  75.0  75.0  36.7   9.9  18.7  0.529  0.6
# Stephen Jackson        SF   30  GSW  59.0  59.0  39.6   7.0  16.9  0.414  1.7
# James Harden           SG   28  HOU  72.0  72.0  35.4   9.0  20.1  0.449  3.7
# Paul George            SF   27  OKC  79.0  79.0  36.6   7.3  17.0  0.430  3.1
# Nikola Jokić            C   22  DEN  75.0  73.0  32.6   6.7  13.5  0.499  1.5
# Stephen Curry          PG   29  GSW  51.0  51.0  32.0   8.4  16.9  0.495  4.2
# Damian Lillard         PG   27  POR  73.0  73.0  36.6   8.5  19.4  0.439  3.1
# ...                    ..  ...  ...   ...   ...   ...   ...   ...    ...  ...
# Paul George             3.3  0.352
# Nikola Jokić            5.6  0.210
# Stephen Curry           4.4  0.173
# Damian Lillard          5.9  0.068
# ...                     ...    ...
# Mike Conley             4.3  0.001
# Stephen Curry           6.7  0.922
# James Harden            5.4  0.720
# LeBron James            8.0  0.425
# Russell Westbrook       3.0  0.271
# Anthony Davis           3.9  0.156
# Chris Paul              5.2  0.095
# LaMarcus Aldridge       1.5  0.005
# Amar'e Stoudemire       1.5  0.004
# Marc Gasol              2.4  0.002
# Blake Griffin           4.8  0.002
# Tim Duncan              2.8  0.001
# Kawhi Leonard           3.8  0.001
# Klay Thompson           1.9  0.001
# Stephen Curry           7.9  1.000
# Kawhi Leonard           4.1  0.484
# LeBron James            5.9  0.482
# Russell Westbrook       7.6  0.371
# Kevin Durant            1.9  0.112
# Manu Ginóbili           2.4  0.002
# Chris Paul              6.9  0.082
# Draymond Green          4.4  0.038
# Damian Lillard          5.2  0.020
# James Harden            7.8  0.007
# Kyle Lowry              3.4  0.005
# Russell Westbrook       8.3  0.879
# James Harden            6.9  0.746
# Kawhi Leonard           6.2  0.495
# LeBron James            7.6  0.330
# Isaiah Thomas           3.3  0.080
#
# [131 rows x 49 columns]

# %%
train_data.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%',
#        '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
#        'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP',
#        'Share'],
#       dtype='object')

# %%
train_data = train_data.dropna(axis=0)

# %%
y = train_data.Share

# %%
features = ['VORP', 'WS', 'STL', 'FG', 'MP', 'OWS','WS/48','PTS', 'PER', 'BLK%']

# %%
X = train_data[features]

# %%
X.describe()
# Out:
#              VORP          WS         STL          FG          MP         OWS  \
# count  131.000000  131.000000  131.000000  131.000000  131.000000  131.000000
# mean     4.410687   10.038931    1.358015    7.749618   34.909924    6.675573
# std      2.511857    3.902949    0.492553    1.615662    3.049839    3.241464
# min      0.100000    0.900000    0.500000    3.900000   23.300000    0.100000
# 25%      2.400000    7.250000    1.000000    6.500000   33.300000    4.150000
# 50%      3.900000    9.900000    1.300000    7.900000   35.500000    6.700000
# 75%      5.850000   12.800000    1.700000    9.000000   37.000000    8.650000
# max     12.400000   20.300000    2.500000   10.800000   39.600000   14.600000
#
#             WS/48         PTS         PER        BLK%
# count  131.000000  131.000000  131.000000  131.000000
# mean     0.193397   21.828244   23.339695    1.803053
# std      0.055445    5.030175    3.918451    1.622483
# min      0.045000   10.200000   13.600000    0.100000
# 25%      0.158000   17.800000   20.550000    0.600000
# 50%      0.195000   22.200000   23.500000    1.300000
# 75%      0.227000   26.150000   26.100000    2.400000
# max      0.322000   31.600000   31.700000    7.700000

# %%
X.head()
# Out:
#      VORP    WS  STL    FG    MP   OWS  WS/48   PTS   PER  BLK%
# 0    11.6  20.3  1.7   9.7  37.7  13.7  0.318  28.4  31.7   2.4
# 1     2.8   7.9  1.3   8.9  39.0   5.2  0.132  25.3  20.8   1.4
# 10    3.2  10.1  1.2   5.2  35.3   7.9  0.174  17.7  18.8   0.5
# 100   9.8  17.9  2.1  10.2  34.2  13.8  0.318  30.1  31.5   0.4
# 101   3.2   7.1  1.2   6.4  35.3   4.2  0.121  16.9  18.8   3.4

# %%
from sklearn.tree import DecisionTreeRegressor

# Define model. Specify a number for random_state to ensure same results each run
melbourne_model = DecisionTreeRegressor(random_state=1)

# Fit model
melbourne_model.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=1, splitter='best')

# %%
print("Making predictions for the following 5 players:")
print(X.head())
print("The predictions are")
print(melbourne_model.predict(X.head()))
# Out:
# Making predictions for the following 5 players:
#      VORP    WS  STL    FG    MP   OWS  WS/48   PTS   PER  BLK%
# 0    11.6  20.3  1.7   9.7  37.7  13.7  0.318  28.4  31.7   2.4
# 1     2.8   7.9  1.3   8.9  39.0   5.2  0.132  25.3  20.8   1.4
# 10    3.2  10.1  1.2   5.2  35.3   7.9  0.174  17.7  18.8   0.5
# 100   9.8  17.9  2.1  10.2  34.2  13.8  0.318  30.1  31.5   0.4
# 101   3.2   7.1  1.2   6.4  35.3   4.2  0.121  16.9  18.8   3.4
# The predictions are
# [0.98  0.495 0.001 0.051 0.007]

# %%
from sklearn.metrics import mean_absolute_error

predicted_player_share = melbourne_model.predict(X)
mean_absolute_error(y, predicted_player_share)
# Out:
# 1.986324590813138e-20

# %%
from sklearn.model_selection import train_test_split

# %%
# split data into training and validation data, for both features and target
# The split is based on a random number generator. Supplying a numeric value to
# the random_state argument guarantees we get the same split every time we
# run this script.
train_X, val_X, train_y, val_y = train_test_split(X, y, test_size=0.3, random_state = 0)

# Define model
model = DecisionTreeRegressor()
# Fit model
model.fit(train_X, train_y)

# get predicted prices on validation data
val_predictions = model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 0.245175

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %f" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  0.201978
# Max leaf nodes: 50  		 Mean Absolute Error:  0.205320
# Max leaf nodes: 500  		 Mean Absolute Error:  0.207350
# Max leaf nodes: 5000  		 Mean Absolute Error:  0.207350

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)
share_preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, share_preds))
# Out:
# 0.17022500000000002
# C:\Users\ying\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(10, include_bias=False)
poly.fit_transform(X)
# Out:
# array([[1.16000000e+01, 2.03000000e+01, 1.70000000e+00, ...,
#         1.10613582e+06, 8.37452990e+04, 6.34033810e+03],
#        [2.80000000e+00, 7.90000000e+00, 1.30000000e+00, ...,
#         6.38485377e+03, 4.29749773e+02, 2.89254655e+01],
#        [3.20000000e+00, 1.01000000e+01, 1.20000000e+00, ...,
#         1.38062500e+00, 3.67187500e-02, 9.76562500e-04],
#        ...,
#        [6.20000000e+00, 1.37000000e+01, 1.80000000e+00, ...,
#         5.29382260e+05, 4.68299692e+04, 4.14265112e+03],
#        [7.60000000e+00, 1.36000000e+01, 1.40000000e+00, ...,
#         1.93818604e+04, 1.05719238e+03, 5.76650391e+01],
#        [3.30000000e+00, 9.70000000e+00, 1.10000000e+00, ...,
#         3.03282225e-02, 4.23184500e-04, 5.90490000e-06]])

# %%
from sklearn.pipeline import make_pipeline
poly_model = make_pipeline(PolynomialFeatures(7), LinearRegression())
